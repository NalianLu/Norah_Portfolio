# %%
# library
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('BankChurners.csv')
df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# 1              44  ...        8256.0                  864           7392.0
# 2              36  ...        3418.0                    0           3418.0
# 3              34  ...        3313.0                 2517            796.0
# 4              21  ...        4716.0                    0           4716.0
#
#    Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  \
# 0                 1.335             1144              42                1.625
# 1                 1.541             1291              33                3.714
# 2                 2.594             1887              20                2.333
# 3                 1.405             1171              20                2.333
# 4                 2.175              816              28                2.500
#
#    Avg_Utilization_Ratio  \
# 0                  0.061
# 1                  0.105
# 2                  0.000
# 3                  0.760
# 4                  0.000
#
#    Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1  \
# 0                                           0.000093
# 1                                           0.000057
# 2                                           0.000021
# 3                                           0.000134
# 4                                           0.000022
#
#    Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2
# 0                                            0.99991
# 1                                            0.99994
# 2                                            0.99998
# 3                                            0.99987
# 4                                            0.99998
#
# [5 rows x 23 columns]

# %% [markdown]
# # Basic Info

# %%
df.shape
# Out:
# (10127, 23)

# %%
df.columns
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'],
#       dtype='object')

# %% [markdown]
# Field Explanation:
# * CLIENTNUM：Client number - Unique identifier for the customer holding the account
# * Attrition_Flag：Flag indicative of account closure in next 6 months (between Jan to Jun 2013)
# * Customer_Age：Age of the account holder
# * Gender：Gender of the account holder
# * Dependent_count：Number of people financially dependent on the account holder
# * Education_Level：Educational qualification of account holder (ex - high school, college grad etc.)
# * Marital_Status：Marital status of account holder (Single, Married, Divorced, Unknown)
# * Income_Category：Annual income category of the account holder
# * Card_Category：Card type depicting the variants of the cards by value proposition (Blue, Silver and Platinum)
# * Months_on_book：Number of months since the account holder opened an an account with the lender
# * Total_Relationship_Count：Total number of products held by the customer. Total number of relationships the account holder has with the bank (example - * retail bank, mortgage, wealth management etc.)
# * Months_Inactive_12_mon：Total number of months inactive in last 12 months
# * Contacts_Count_12_mon：Number of Contacts in the last 12 months. No. of times the account holder called to the call center in the past 12 months
# * Credit_Limit：Credit limit
# * Total_Revolving_Bal：Total amount as revolving balance
# * Avg_Open_To_Buy：Open to Buy Credit Line (Average of last 12 months)
# * Total_Amt_Chng_Q4_Q1：Change in Transaction Amount (Q4 over Q1)
# * Total_Trans_Amt：Total Transaction Amount (Last 12 months)
# * Total_Trans_Ct：Total Transaction Count (Last 12 months)
# * Total_Ct_Chng_Q4_Q1：Change in Transaction Count (Q4 over Q1)
# * Avg_Utilization_Ratio：Average Card Utilization Ratio
# * Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1: generated, not sure, delete!
# * Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2: generated, not sure, delete!

# %%
df = df.iloc[:, :-2] # drop last 2 columns
df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0              39  ...                       1                      3
# 1              44  ...                       1                      2
# 2              36  ...                       1                      0
# 3              34  ...                       4                      1
# 4              21  ...                       1                      0
#
#    Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  \
# 0       12691.0                  777          11914.0                 1.335
# 1        8256.0                  864           7392.0                 1.541
# 2        3418.0                    0           3418.0                 2.594
# 3        3313.0                 2517            796.0                 1.405
# 4        4716.0                    0           4716.0                 2.175
#
#    Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# 0             1144              42                1.625                  0.061
# 1             1291              33                3.714                  0.105
# 2             1887              20                2.333                  0.000
# 3             1171              20                2.333                  0.760
# 4              816              28                2.500                  0.000
#
# [5 rows x 21 columns]

# %%
pd.value_counts(df.dtypes)
# Out:
# int64      10
# object      6
# float64     5
# dtype: int64

# %%
df.describe().style.background_gradient()
# Out:
# <style type="text/css">
# #T_d1d19_row0_col0, #T_d1d19_row1_col1, #T_d1d19_row1_col2, #T_d1d19_row1_col3, #T_d1d19_row1_col4, #T_d1d19_row1_col5, #T_d1d19_row1_col6, #T_d1d19_row1_col10, #T_d1d19_row1_col13, #T_d1d19_row1_col14, #T_d1d19_row2_col1, #T_d1d19_row2_col2, #T_d1d19_row2_col3, #T_d1d19_row2_col4, #T_d1d19_row2_col5, #T_d1d19_row2_col6, #T_d1d19_row2_col10, #T_d1d19_row2_col12, #T_d1d19_row2_col13, #T_d1d19_row2_col14, #T_d1d19_row3_col1, #T_d1d19_row3_col2, #T_d1d19_row3_col3, #T_d1d19_row3_col4, #T_d1d19_row3_col5, #T_d1d19_row3_col6, #T_d1d19_row3_col7, #T_d1d19_row3_col8, #T_d1d19_row3_col9, #T_d1d19_row3_col10, #T_d1d19_row3_col11, #T_d1d19_row3_col12, #T_d1d19_row3_col13, #T_d1d19_row3_col14, #T_d1d19_row4_col1, #T_d1d19_row4_col2, #T_d1d19_row4_col3, #T_d1d19_row4_col4, #T_d1d19_row4_col5, #T_d1d19_row4_col6, #T_d1d19_row4_col10, #T_d1d19_row4_col12, #T_d1d19_row4_col13, #T_d1d19_row4_col14, #T_d1d19_row5_col1, #T_d1d19_row5_col2, #T_d1d19_row5_col3, #T_d1d19_row5_col4, #T_d1d19_row5_col5, #T_d1d19_row5_col6, #T_d1d19_row5_col10, #T_d1d19_row5_col13, #T_d1d19_row5_col14, #T_d1d19_row6_col2, #T_d1d19_row6_col3, #T_d1d19_row6_col4, #T_d1d19_row6_col5, #T_d1d19_row6_col6, #T_d1d19_row6_col10, #T_d1d19_row6_col13, #T_d1d19_row6_col14, #T_d1d19_row7_col2, #T_d1d19_row7_col4, #T_d1d19_row7_col5, #T_d1d19_row7_col6, #T_d1d19_row7_col10, #T_d1d19_row7_col13, #T_d1d19_row7_col14 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_d1d19_row0_col1, #T_d1d19_row0_col2, #T_d1d19_row0_col3, #T_d1d19_row0_col4, #T_d1d19_row0_col5, #T_d1d19_row0_col6, #T_d1d19_row0_col8, #T_d1d19_row0_col10, #T_d1d19_row0_col12, #T_d1d19_row0_col13, #T_d1d19_row0_col14, #T_d1d19_row7_col0, #T_d1d19_row7_col7, #T_d1d19_row7_col9, #T_d1d19_row7_col11 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_d1d19_row0_col7, #T_d1d19_row2_col9 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_d1d19_row0_col9 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_d1d19_row0_col11 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_d1d19_row1_col0 {
#   background-color: #045585;
#   color: #f1f1f1;
# }
# #T_d1d19_row1_col7, #T_d1d19_row1_col9, #T_d1d19_row1_col11 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_d1d19_row1_col8 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_d1d19_row1_col12, #T_d1d19_row5_col12, #T_d1d19_row6_col1, #T_d1d19_row6_col12, #T_d1d19_row7_col1, #T_d1d19_row7_col3 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_d1d19_row2_col0 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_d1d19_row2_col7 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_d1d19_row2_col8 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_d1d19_row2_col11 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_d1d19_row3_col0 {
#   background-color: #045e93;
#   color: #f1f1f1;
# }
# #T_d1d19_row4_col0 {
#   background-color: #045c90;
#   color: #f1f1f1;
# }
# #T_d1d19_row4_col7 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_d1d19_row4_col8, #T_d1d19_row4_col9 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_d1d19_row4_col11 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_d1d19_row5_col0 {
#   background-color: #045b8f;
#   color: #f1f1f1;
# }
# #T_d1d19_row5_col7 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_d1d19_row5_col8 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_d1d19_row5_col9 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_d1d19_row5_col11 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_d1d19_row6_col0 {
#   background-color: #034a74;
#   color: #f1f1f1;
# }
# #T_d1d19_row6_col7 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_d1d19_row6_col8 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_d1d19_row6_col9 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_d1d19_row6_col11 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_d1d19_row7_col8 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_d1d19_row7_col12 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# </style>
# <table id="T_d1d19">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d1d19_level0_col0" class="col_heading level0 col0" >CLIENTNUM</th>
#       <th id="T_d1d19_level0_col1" class="col_heading level0 col1" >Customer_Age</th>
#       <th id="T_d1d19_level0_col2" class="col_heading level0 col2" >Dependent_count</th>
#       <th id="T_d1d19_level0_col3" class="col_heading level0 col3" >Months_on_book</th>
#       <th id="T_d1d19_level0_col4" class="col_heading level0 col4" >Total_Relationship_Count</th>
#       <th id="T_d1d19_level0_col5" class="col_heading level0 col5" >Months_Inactive_12_mon</th>
#       <th id="T_d1d19_level0_col6" class="col_heading level0 col6" >Contacts_Count_12_mon</th>
#       <th id="T_d1d19_level0_col7" class="col_heading level0 col7" >Credit_Limit</th>
#       <th id="T_d1d19_level0_col8" class="col_heading level0 col8" >Total_Revolving_Bal</th>
#       <th id="T_d1d19_level0_col9" class="col_heading level0 col9" >Avg_Open_To_Buy</th>
#       <th id="T_d1d19_level0_col10" class="col_heading level0 col10" >Total_Amt_Chng_Q4_Q1</th>
#       <th id="T_d1d19_level0_col11" class="col_heading level0 col11" >Total_Trans_Amt</th>
#       <th id="T_d1d19_level0_col12" class="col_heading level0 col12" >Total_Trans_Ct</th>
#       <th id="T_d1d19_level0_col13" class="col_heading level0 col13" >Total_Ct_Chng_Q4_Q1</th>
#       <th id="T_d1d19_level0_col14" class="col_heading level0 col14" >Avg_Utilization_Ratio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d1d19_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_d1d19_row0_col0" class="data row0 col0" >10127.000000</td>
#       <td id="T_d1d19_row0_col1" class="data row0 col1" >10127.000000</td>
#       <td id="T_d1d19_row0_col2" class="data row0 col2" >10127.000000</td>
#       <td id="T_d1d19_row0_col3" class="data row0 col3" >10127.000000</td>
#       <td id="T_d1d19_row0_col4" class="data row0 col4" >10127.000000</td>
#       <td id="T_d1d19_row0_col5" class="data row0 col5" >10127.000000</td>
#       <td id="T_d1d19_row0_col6" class="data row0 col6" >10127.000000</td>
#       <td id="T_d1d19_row0_col7" class="data row0 col7" >10127.000000</td>
#       <td id="T_d1d19_row0_col8" class="data row0 col8" >10127.000000</td>
#       <td id="T_d1d19_row0_col9" class="data row0 col9" >10127.000000</td>
#       <td id="T_d1d19_row0_col10" class="data row0 col10" >10127.000000</td>
#       <td id="T_d1d19_row0_col11" class="data row0 col11" >10127.000000</td>
#       <td id="T_d1d19_row0_col12" class="data row0 col12" >10127.000000</td>
#       <td id="T_d1d19_row0_col13" class="data row0 col13" >10127.000000</td>
#       <td id="T_d1d19_row0_col14" class="data row0 col14" >10127.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d1d19_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_d1d19_row1_col0" class="data row1 col0" >739177606.333663</td>
#       <td id="T_d1d19_row1_col1" class="data row1 col1" >46.325960</td>
#       <td id="T_d1d19_row1_col2" class="data row1 col2" >2.346203</td>
#       <td id="T_d1d19_row1_col3" class="data row1 col3" >35.928409</td>
#       <td id="T_d1d19_row1_col4" class="data row1 col4" >3.812580</td>
#       <td id="T_d1d19_row1_col5" class="data row1 col5" >2.341167</td>
#       <td id="T_d1d19_row1_col6" class="data row1 col6" >2.455317</td>
#       <td id="T_d1d19_row1_col7" class="data row1 col7" >8631.953698</td>
#       <td id="T_d1d19_row1_col8" class="data row1 col8" >1162.814061</td>
#       <td id="T_d1d19_row1_col9" class="data row1 col9" >7469.139637</td>
#       <td id="T_d1d19_row1_col10" class="data row1 col10" >0.759941</td>
#       <td id="T_d1d19_row1_col11" class="data row1 col11" >4404.086304</td>
#       <td id="T_d1d19_row1_col12" class="data row1 col12" >64.858695</td>
#       <td id="T_d1d19_row1_col13" class="data row1 col13" >0.712222</td>
#       <td id="T_d1d19_row1_col14" class="data row1 col14" >0.274894</td>
#     </tr>
#     <tr>
#       <th id="T_d1d19_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_d1d19_row2

# %% [markdown]
# # Null

# %%
total = df.isnull().sum().sort_values(ascending=False)
Percentage = total / len(df)
Percentage
# Out:
# CLIENTNUM                   0.0
# Months_Inactive_12_mon      0.0
# Total_Ct_Chng_Q4_Q1         0.0
# Total_Trans_Ct              0.0
# Total_Trans_Amt             0.0
# Total_Amt_Chng_Q4_Q1        0.0
# Avg_Open_To_Buy             0.0
# Total_Revolving_Bal         0.0
# Credit_Limit                0.0
# Contacts_Count_12_mon       0.0
# Total_Relationship_Count    0.0
# Attrition_Flag              0.0
# Months_on_book              0.0
# Card_Category               0.0
# Income_Category             0.0
# Marital_Status              0.0
# Education_Level             0.0
# Dependent_count             0.0
# Gender                      0.0
# Customer_Age                0.0
# Avg_Utilization_Ratio       0.0
# dtype: float64

# %% [markdown]
# comment: no null value in data set
